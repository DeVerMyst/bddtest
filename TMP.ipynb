# %%
STR = "mon formateur est formidable"
print(STR)
# Out:
# mon formateur est formidable

# %%
STR.upper()
# Out:
# 'MON FORMATEUR EST FORMIDABLE'

# %%
for i,s in enumerate(STR.split()):
    print(f"mot num {i}, valeur {s}")
# Out:
# mot num 0, valeur mon
# mot num 1, valeur formateur
# mot num 2, valeur est
# mot num 3, valeur formidable
